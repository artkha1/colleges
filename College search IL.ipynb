# %% [markdown]
# Attributions:
# * [CollegeScorecard Datasets](https://collegescorecard.ed.gov/data/)
# * [CollegeAI API - although not used in this project, great for receiving info about a specific college](https://api.collegeai.com/v1/docs)
# * [PyScorecard GitHub code - looked at it for a while trying to understand why filtering by state doesn't work, eventually gave up. Still a good source for inspiration :)](https://github.com/deino475/PyScorecard/blob/master/PyScorecard/PyScorecard.py)
# * [Detailed CollegeScorecard documentation that expains what each variable means](https://collegescorecard.ed.gov/assets/FullDataDocumentation.pcollegeInfo)
# * [Basics of how to use the CollegeScorecard API](https://collegescorecard.ed.gov/data/documentation/). See the Data Dictionary file for the complete list of fields
# * [Detailed description of every feature of the CollegeScorecard API](https://github.com/RTICWDT/open-data-maker/blob/master/API.md)
# *[IPEDS - used here for some additional features](https://nces.ed.gov/ipeds/datacenter/InstitutionByName.aspx?goToReportId=1)

# %%
#get all the data from the CollegeScorecard API
import requests
import math
import numpy as np
from IPython.display import display
import webbrowser
import pyinputplus as pyip
import pandas as pd

key = "nyiNevdtUIEMrkovbB6bYPDsdi8V4rRBSEzXtN9s"
url_base = "https://api.data.gov/ed/collegescorecard/v1/schools/"
fields = ','.join([
    "location.lat","location.lon",
    "school.religious_affiliation","school.name","school.alias","school.city","school.state","school.zip","school.ownership_peps","school.school_url","school.locale","school.institutional_characteristics.level",
    "latest.admissions.admission_rate.overall","latest.admissions.sat_scores.midpoint.critical_reading","latest.admissions.sat_scores.midpoint.writing","latest.admissions.sat_scores.midpoint.math","latest.admissions.act_scores.midpoint.cumulative",
    "latest.academics.program_percentage.computer","latest.academics.program_percentage.mathematics",
    "latest.student.demographics.median_hh_income","latest.student.size","latest.student.demographics.female_share","latest.student.demographics.race_ethnicity.white","latest.student.demographics.race_ethnicity.black","latest.student.demographics.race_ethnicity.hispanic","latest.student.demographics.race_ethnicity.asian",
    "latest.cost.net_price.public.by_income_level.48001-75000","latest.cost.net_price.public.by_income_level.75001-110000","latest.cost.attendance.academic_year","latest.cost.tuition.in_state","latest.cost.tuition.out_of_state",
    "latest.aid.federal_loan_rate",
    "latest.earnings.10_yrs_after_entry.median","latest.earnings.6_yrs_after_entry.median",
])

def get_col_data(page):
    p = {
    "school.men_only":"0", "school.women_only":"0", "school.online_only":"0", "school.operating":"1",
    "school.state":"IL", #can change it to region (3 is midwest) or remove location altogether
    "fields":fields,
    "zip":"60056",
    "distance":"150mi", #only return colleges within 150 miles from my zip
    #"sort":"latest.student.demographics.median_hh_income:desc", #sort the results. Default: asc, add :desc to the field to do descending. EG: "sort":"latest.student.demographics.median_hh_income:desc"
    "page":page, 
    "api_key": key
    }
    resp = requests.get(url=url_base, params=p)
    return resp.json()

try:
    metadata = get_col_data(0)['metadata']
except:
    print(get_col_data(0)) #print the error

all_pages = []
for i in range(math.ceil(metadata['total']/metadata['per_page'])):
    all_pages.extend(get_col_data(i)['results']) #add data from all pages

# %%
#Turn it into dataframe, make it look nice
collegeInfo = pd.DataFrame(all_pages).set_index('school.name').fillna(value=np.nan)
collegeInfo = collegeInfo[~collegeInfo.index.duplicated(keep='last')] #remove duplicates

#If there is a year (latest in this case), remove it from column name. Also remove the dev category
collegeInfo = collegeInfo.rename(columns = lambda x: '.'.join(x.split('.')[2:]) if 'latest' in x else x) #turn latest.admissions.admission_rate.overall into admission_rate.overall.
collegeInfo = collegeInfo.reindex(sorted(collegeInfo.columns), axis=1) #sort column names alphabetically to make it easier to rename them

#manually rename the columns
#NOTE: median is used for all the calculations aside from net price
newNames = [
    'Salary 10 years after entry','Salary 6 years after entry',
    'Cumulative ACT score','Admission rate','Overall annual cost of attendance',
    '% female','Household income','% Asian','% Black','% Hispanic','% White','% with a federal loan',
    'Latitude','Longtitude',
    'Net price for $48001-75000 household income','Net price for $75001-110000 household income',
    '% students in computer science','% students in math',
    'SAT Reading','SAT Math','SAT Writing',
    'Aliases',
    'City','Level of institution','Locale',
    'Ownership','Religious affiliation','Website',
    'State','ZIP',
    '# students',
    'In-state tuition','Out-of-state tuition'
]
collegeInfo.columns = newNames

#manually rename the index
collegeInfo.index.names = ['Name'] #instead of school.name

#reoder the column names with a custom order
newOrder = [
    'Religious affiliation',
    'Salary 10 years after entry','Salary 6 years after entry',
    'Admission rate',
    '% female','% Asian','% Black','% Hispanic','% White',
    '% students in computer science','% students in math',
    'Cumulative ACT score','SAT Reading','SAT Math','SAT Writing',
    'Aliases',
    'City',
    'Level of institution',
    'Locale',
    'Ownership',
    'Website',
    'State',
    'ZIP','Latitude','Longtitude',
    '# students',
    'Household income',
    '% with a federal loan',
    'Net price for $48001-75000 household income','Net price for $75001-110000 household income',
    'Overall annual cost of attendance','In-state tuition','Out-of-state tuition'
]
collegeInfo = collegeInfo[newOrder]
#Ownership, level of instituion, and locale columns contain numbers that correspond to certain values - map them
#Religion will be mapped later
localeDic = {
    11:'Large City',12:'Midsize City',13:'Small City',
    21:'Large Suburb',22:'Midsize Suburb',23:'Small Suburb',
    31:'Fringe Town',32:'Distant Town',33:'Remote Town',
    41:'Fringe Rural',42:'Distant Rural',43:'Remote Rural',
}
ownDic = {1:'Public',2:'Private, Nonprofit',3:'Proprietary'}
levelDic = {1:'4-year',2:'2-year',3:'Less-than-2-year'}

collegeInfo['Locale'] = collegeInfo['Locale'].map(localeDic)
collegeInfo['Ownership'] = collegeInfo['Ownership'].map(ownDic)
collegeInfo['Level of institution'] = collegeInfo['Level of institution'].map(levelDic)

states = {"AL":"Alabama","AK":"Alaska","AZ":"Arizona","AR":"Arkansas","CA":"California","CO":"Colorado","CT":"Connecticut","DE":"Delaware","FL":"Florida","GA":"Georgia","HI":"Hawaii","ID":"Idaho","IL":"Illinois","IN":"Indiana","IA":"Iowa","KS":"Kansas","KY":"Kentucky","LA":"Louisiana","ME":"Maine","MD":"Maryland","MA":"Massachusetts","MI":"Michigan","MN":"Minnesota","MS":"Mississippi","MO":"Missouri","MT":"Montana","NE":"Nebraska","NV":"Nevada","NH":"New Hampshire","NJ":"New Jersey","NM":"New Mexico","NY":"New York","NC":"North Carolina","ND":"North Dakota","OH":"Ohio","OK":"Oklahoma","OR":"Oregon","PA":"Pennsylvania","RI":"Rhode Island","SC":"South Carolina","SD":"South Dakota","TN":"Tennessee","TX":"Texas","UT":"Utah","VT":"Vermont","VA":"Virginia","WA":"Washington","WV":"West Virginia","WI":"Wisconsin","WY":"Wyoming"}
collegeInfo['State'] = collegeInfo['State'].map(states) #rename state abbreviations to full names

# %%
#combine it with another dataset that i got straight from the IPEDS. Data is from 2018/19
ipedsCols = [
    'instnm','Address',
    "Number of students receiving a Doctor's degree (DRVC2018)",
    "Number of students receiving a Master's degree (DRVC2018)",
    "Number of students receiving a Bachelor's degree (DRVC2018)",
    "Number of students receiving an Associate's degree (DRVC2018)",
    'Graduation rate','Average amount of aid awarded'
]
ipeds = pd.read_csv(r'C:\Users\timkh\OneDrive\Desktop\Programming\Projects\Colleges\IPEDS.csv',usecols=ipedsCols).set_index('instnm').replace(r'^\s*$', np.nan, regex=True) # replace field that's entirely space (or empty) with NaN
#set the graduate # to the sum of # of PhD, # of Masters, # of Bachleors, and # of Associates graduating. This ensures the percentages are correct
ipeds['Graduate #'] = ipeds["Number of students receiving a Doctor's degree (DRVC2018)"]+ipeds["Number of students receiving a Master's degree (DRVC2018)"]+ipeds["Number of students receiving a Bachelor's degree (DRVC2018)"]+ipeds["Number of students receiving an Associate's degree (DRVC2018)"]
ipeds["% receiving Doctor's"] = ipeds["Number of students receiving a Doctor's degree (DRVC2018)"]/ipeds['Graduate #']
ipeds["% receiving Master's"] = ipeds["Number of students receiving a Master's degree (DRVC2018)"]/ipeds['Graduate #']
ipeds["% receiving Bachelor's"] = ipeds["Number of students receiving a Bachelor's degree (DRVC2018)"]/ipeds['Graduate #']
ipeds["% receiving Associate's"] = ipeds["Number of students receiving an Associate's degree (DRVC2018)"]/ipeds['Graduate #']
#drop the columns that aren't needed anymore
ipeds.drop(["Number of students receiving a Doctor's degree (DRVC2018)",
    "Number of students receiving a Master's degree (DRVC2018)",
    "Number of students receiving a Bachelor's degree (DRVC2018)",
    "Number of students receiving an Associate's degree (DRVC2018)", "Graduate #"],axis=1,inplace=True)

#merge
collegeInfo = pd.merge(collegeInfo,ipeds,how='left',left_index=True,right_index=True)

# %%
#multiply all percentages by 100 and round numbers
for col in collegeInfo.columns:
    if '%' in col or col == 'Admission rate':
        collegeInfo[col] = collegeInfo[col].map(lambda x: x*100 if x<=1 else x)
collegeInfo = collegeInfo.round(2)

#remove the stuff after hyphen in zip+4
#collegeInfo['ZIP'] = collegeInfo['ZIP'].apply(lambda x: x[:x.index('-')] if '-' in x else x)

#add a new column with the distance of the college from home
def get_distance(row):
    lat1 = math.radians(row['Latitude'])
    lon1 = math.radians(row['Longtitude'])
    lat2=math.radians(42.04)
    lon2=math.radians(-87.94)
    
    r = 3958.8 #radius of the Earth
    dlon = lon2 - lon1 #change in coordinates
    dlat = lat2 - lat1
    a = math.sin(dlat / 2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon / 2)**2 #Haversine formula
    c = 2 * math.atan2(math.sqrt(a), math.sqrt(1 - a))
    distance = r * c
    return round(distance,2)
collegeInfo['Approximate distance from home (mi)'] = collegeInfo.apply(get_distance,axis=1)
collegeInfo.drop(['Latitude','Longtitude'],axis=1,inplace=True) #delete the columns that aren't needed anymore

# %%
#Done! Now just apply the needed filters! Ignore the NaN values
#| math.isnan(collegeInfo[Column]) makes sure that NaN values aren't accidentally filtered out
#can add act, 3 sats
collegeInfo = collegeInfo[(collegeInfo['Religious affiliation']==30) | (collegeInfo['Religious affiliation'].apply(math.isnan))].dropna(thresh=20) #remove religious (non-Catholic universities) and those that have 20 or more NaN values
collegeInfo['Religious affiliation'] = collegeInfo['Religious affiliation'].map({30:'Roman Catholic'})
filtered = collegeInfo[
    ((collegeInfo['Salary 10 years after entry'] >= 40000) | (collegeInfo['Salary 10 years after entry'].apply(math.isnan))) &
    #(collegeInfo['Salary 6 years after entry'] >= 50000) &
    #(collegeInfo['Admission rate'] >= 50) &
    ((collegeInfo['% female'] <= 65) | (collegeInfo['% female'].apply(math.isnan))) &
    #(3 <= collegeInfo['% Asian'] <= 20) &
    (((collegeInfo['% Black'] > 0) & (collegeInfo['% Black'] < 10)) | (collegeInfo['% Black'].apply(math.isnan))) &
    #(1 <= collegeInfo['% Hispanic'] <= 15) &
    (((collegeInfo['% White'] > 27) & (collegeInfo['% White'] < 90)) | (collegeInfo['% White'].apply(math.isnan))) &
    ((collegeInfo['% students in computer science'] > 0) | (collegeInfo['% students in computer science'].apply(math.isnan))) #&
    #(collegeInfo['% students in math'] > 0) & 
    #(collegeInfo['# students'] >= 5000) & 
    #(35000 <= collegeInfo['Household income'] <= 100000) &
    #(collegeInfo['Overall annual cost of attendance'] <= 25000) &
    #(collegeInfo['In-state tuition'] <= 17000) &
    #(collegeInfo['Approximate distance from home (mi)'] <= 60)
]
filtered
# Out:
#                                            Religious affiliation  \
# Benedictine University                            Roman Catholic
# Bradley University                                           NaN
# DePaul University                                 Roman Catholic
# Illinois Institute of Technology                             NaN
# Illinois State University                                    NaN
# Illinois Wesleyan University                                 NaN
# Lake Forest College                                          NaN
# Lewis University                                  Roman Catholic
# Morrison Institute of Technology                             NaN
# Northwestern University                                      NaN
# Rockford University                                          NaN
# University of Chicago                                        NaN
# University of Illinois at Chicago                            NaN
# University of Illinois at Urbana-Champaign                   NaN
# University of St Francis                          Roman Catholic
#
#                                             Salary 10 years after entry  \
# Benedictine University                                          49000.0
# Bradley University                                              53600.0
# DePaul University                                               53300.0
# Illinois Institute of Technology                                69100.0
# Illinois State University                                       47100.0
# Illinois Wesleyan University                                    59100.0
# Lake Forest College                                             50900.0
# Lewis University                                                48800.0
# Morrison Institute of Technology                                51400.0
# Northwestern University                                         69000.0
# Rockford University                                             45200.0
# University of Chicago                                           68100.0
# University of Illinois at Chicago                               54300.0
# University of Illinois at Urbana-Champaign                      61500.0
# University of St Francis                                        53100.0
#
#                                             Salary 6 years after entry  \
# Benedictine University                                         40000.0
# Bradley University                                             42900.0
# DePaul University                                              42100.0
# Illinois Institute of Technology                               55800.0
# Illinois State University                                      39600.0
# Illinois Wesleyan University                                   41600.0
# Lake Forest College                                            39100.0
# Lewis University                                               40700.0
# Morrison Institute of Technology                               37600.0
# Northwestern University                                        58900.0
# Rockford University                                            36600.0
# University of Chicago                                          54300.0
# University of Illinois at Chicago                              39600.0
# University of Illinois at Urbana-Champaign                     47100.0
# University of St Francis                                       44100.0
#
#                                             Admission rate  % female  % Asian  \
# Benedictine University                               62.83     57.61    14.56
# Bradley University                                   66.81     52.99     3.46
# DePaul University                                    67.53     55.00     9.84
# Illinois Institute of Technology                     58.18     30.01    15.08
# Illinois State University                            89.18     56.24     2.11
# Illinois Wesleyan University                         58.55     52.27     5.52
# Lake Forest College                                  57.92     60.30     5.18
# Lewis University                                     57.76     54.92     5.12
# Morrison Institute of Technology                       NaN       NaN     0.00
# Northwestern University                               8.47     52.43    17.34
# Rockford University                                  49.03     57.00     2.37
# University of Chicago                                 7.26     51.91    19.18
# University of Illinois at Chicago                    75.55     52.85    21.20
# University of Illinois at Urbana-Champaign           62.16     49.48    18.95
# University of St Francis                             46.78     64.48     2.70
#
#                                             % Black  % Hispanic  % White  \
# Benedictine University                         8.58       17.50    41.94
# Bradley University                             6.94       10.37    72.73
# DePaul University                              7.86       18.69    52.44
# Illinois Institute of Technology               5.16       16.52    36.35
# Illinois State University                      9.31       11.06    73.13
# Illinois Wesleyan University                   6.17        9.43    69.57
# Lake Forest College                            4.98       14.32    57.50
# Lewis University                               5.55       20.75    59.02
# Morrison Institute of Technology               0.86        9.48    80.17
# Northwestern University                        5.94       12.52    45.46
# Rockford University                            9.88       17.18    59.57
# University of Chicago                          5.18       13.68    39.30
# University of Illinois at Chicago              7.91       34.03    28.32
# University of Illinois at Urbana-Champaign     6.04       12.03    44.22
# University of St Francis                       9.75       19.94    60.06
#
#                                             % students in computer science  \
# Benedictine University                                                1.83
# Bradley University                                                    3.98
# DePaul University                                                     7.35
# Illinois Institute of Technology                                     16.99
# Illinois State University                                             2.79
# Illinois Wesleyan University                                          1.98
# Lake Forest College                                                   1.31
# Lewis University                                                      8.31
# Morrison Institute of Technology                                     24.14
# Northwestern University                                               5.27
# Rockford University                                                   1.48
# University of Chicago                                                 4.81
# University of Illinois at Chicago                                     6.26
# University of Illinois at Urbana-Champaign                            4.67
# University of St Francis                                              1.21
#
#                                             ...  In-state tuition  \
# Benedictine University                      ...           34290.0
# Bradley University                          ...           33760.0
# DePaul University                           ...           39975.0
# Illinois Institute of Technology            ...           47646.0
# Illinois State University                   ...           14516.0
# Illinois Wesleyan University                ...           47636.0
# Lake Forest College                         ...           47064.0
# Lewis University                            ...           32450.0
# Morrison Institute of Technology            ...           16100.0
# Northwestern University                     ...           54568.0
# Rockford University                         ...           30930.0
# University of Chicago                       ...           58230.0
# University of Illinois at Chicago           ...           13764.0
# University of Illinois at Urbana-Champaign  ...           15094.0
# University of St Francis                    ...           32320.0
#
#                                             Out-of-state tuition  \
# Benedictine University                                   34290.0
# Bradley University                                       33760.0
# DePaul University                                        39975.0
# Illinois Institute of Technology                         47646.0
# Illinois State University                                26040.0
# Illinois Wesleyan University                             47636.0
# Lake Forest College                                      47064.0
# Lewis University                                         32450.0
# Morrison Institute of Technology                         16100.0
# Northwestern University                                  54568.0
# Rockford University                                      30930.0
# University of Chicago                                    58230.0
# University of Illinois at Chicago                        26980.0
# University of Illinois at Urbana-Champaign               31664.0
# University of St Francis                                 32320.0
#
#                                                              Address  \
# Benedictine University                               5700 College Rd
# Bradley University                                1501 W Bradley Ave
# DePaul University                                   1 E Jackson Blvd
# Illinois Institute of Technology                 10 West 35th Street
# Illinois State University                   North and School Streets
# Illinois Wesleyan University                          1312 N Park St
# Lake Forest College                              555 N Sheridan Road
# Lewis University                              One University Parkway
# Morrison Institute of Technology                                 NaN
# Northwestern University                                 633 Clark St
# Rockford University                                  5050 E State St
# University of Chicago                               5801 S Ellis Ave
# University of Illinois at Chicago                       601 S Morgan
# University of Illinois at Urbana-Champaign         601 E John Street
# University of St Francis                             500 N Wilcox St
#
#                                             Graduation rate  \
# Benedictine University                                 47.0
# Bradley University                                     78.0
# DePaul University                                      72.0
# Illinois Institute of Technology                       72.0
# Illinois State University                              69.0
# Illinois Wesleyan University                           79.0
# Lake Forest College                                    69.0
# Lewis University                                       64.0
# Morrison Institute of Technology                        NaN
# Northwestern University                                95.0
# Rockford University                                    38.0
# University of Chicago                                  94.0
# University of Illinois at Chicago                      59.0
# University of Illinois at Urbana-Champaign             84.0
# University of St Francis                               62.0
#
#                                             Average amount of aid awarded  \
# Benedictine University                                            18891.0
# Bradley University                                                20186.0
# DePaul University                                                 24112.0
# Illinois Institute of Technology                                  34691.0
# Illinois State University                                          9572.0
# Illinois Wesleyan University                                      27418.0
# Lake Forest College                                               31131.0
# Lewis University                                                  20958.0
# Morrison Institute of Technology                                      NaN
# Northwestern University                                           45427.0
# Rockford University                                               19009.0
# University of Chicago                                             42732.0
# University of Illinois at Chicago                                 12850.0
# University of Illinois at Urbana-Champaign                        14328.0
# University of St Francis                                          21000.0
#
#                                            % receiving Doctor's  \
# Benedictine University                                     1.54
# Bradley University                                         2.03
# DePaul University                                          4.68
# Illinois Institute of Technology                          12.86
# Illinois State University                                  0.96
# Illinois Wesleyan University                               0.00
# Lake Forest College                                        0.00
# Lewis University                                           0.65
# Morrison Institute of Technology                            NaN
# Northwestern University                                   12.68
# Rockford University                                        0.00
# University of Chicago                                     14.28
# University of Illinois at Chicago                         14.50
# University of Illinois at Urbana-Champaign                 8.61
# University of St Francis                                   3.89
#
#                                            % receiving Master's  \
# Benedictine University                                    51.82
# Bradley University                                        20.65
# DePaul University                                         39.54
# Illinois Institute of Technology                          65.56
# Illinois State University                                 12.96
# Illinois Wesleyan University                               0.00
# Lake Forest College                                        4.03
# Lewis University                                          32.55
# Morrison Institute of Technology                            NaN
# Northwestern University                                   59.03
# Rockford University                                       21.28
# University of Chicago                                     58.37
# University of Illinois at Chicago                         31.31
# University of Illinois at Urbana-Champaign                29.70
# University of St Francis                                  53.94
#
#                                            % receiving Bachelor's  \
# Benedictine University                                      46.64
# Bradley University                                          77.32
# DePaul University                                           55.78
# Illinois Institute of Technology                            21.58
# Illinois State University                                   86.08
# Illinois Wesleyan University                               100.00
# Lake Forest College                                         95.97
# Lewis University                                            66.63
# Morrison Institute of Technology                              NaN
# Northwestern University                                     28.29
# Rockford University                                         78.72
# University of Chicago                                       27.35
# University of Illinois at Chicago                           54.19
# University of Illinois at Urbana-Champaign                  61.69
# University of St Francis                                    42.17
#
#                                            % receiving Associate's  \
# Benedictine University                                        0.00
# Bradley University                                            0.00
# DePaul University                                             0.00
# Illinois Institute of Technology                              0.00
# Illinois State University                                     0.00
# Illinois Wesleyan University                                  0.00
# Lake Forest College                                           0.00
# Lewis University                                              0.16
# Morrison Institute of Technology                               NaN
# Northwestern University                                       0.00
# Rockford University                                           0.00
# University of Chicago                                         0.00
# University of Illinois at Chicago                             0.00
# University of Illinois at Urbana-Champaign                    0.00
# University of St Francis                                      0.00
#
#                                            Approximate distance from home (mi)
# Benedictine University                                                   19.76
# Bradley University                                                      127.12
# DePaul University                                                        19.39
# Illinois Institute of Technology                                         21.55
# Illinois State University                                               118.94
# Illinois Wesleyan University                                            120.18
# Lake Forest College                                                      15.57
# Lewis University                                                         30.57
# Morrison Institute of Technology                                        105.67
# Northwestern University                                                  13.36
# Rockford University                                                      57.56
# University of Chicago                                                    24.58
# University of Illinois at Chicago                                        18.97
# University of Illinois at Urbana-Champaign                              134.89
# University of St Francis                                                 36.19
#
# [15 rows x 39 columns]

# %% [markdown]
# The next cell is a custom scoring system. Explanation (footnotes are in the code below):
# 1. Values used in the deviation section are of the perfect university - the more a value deviates from these, the worse. Columns are built with ABSOLUTE deviation from the ideal value for those features, e.g. the perfect admission rate would be 65% (not too high, not too low). Absolute deviation = |x-preferred_value|. Later these deviations will be normalized - those that are far away from the ideal/desired value will be high on a 0 to 100 scale, and those that are close to ideal will be low. Thus, we'd like to minimize this deviation, so we subtract it from the overall score. Higher deviations = lower score. Perfectly fits the criteria = deviation of 0, so nothing gets subtracted from the score. NOTE: normally, the optimal or "ideal" values would be computed through extensive research, formulas, and algorithms. Oftentimes optimal values ar either the mean or the median. However, as this project's "optimal values" are just my ideas of what a good college would look like for ME, they are completely subjective. These values are just what I personally would like to see in my university.
# 2. We now standardize *all* values on a 0-100 scale. To do this, the [min-max normalization/feature scaling technique](https://en.wikipedia.org/wiki/Feature_scaling#Methods) is utilized. It shows how each university compares to other universities - a value closer to 100 means that particular feature is higher than most other counterparts'. We will want some features (like salary) maximized, and some (like cost and deviation from perfection) minimized. The score is calculated by adding all the standardized features that need to be maximized. From this score, we then subtract the sum of all the standardized features that need to be minimized. If a value is NaN, it becomes 0 or 100 depending on whether it needs to be minimized or maximized. NaN + or - any number will be NaN, but by filling NaNs we ensure that no college will receive a score of NaN, however they are still going to have a disadvantage compared to the colleges without any NaNs. While adding and subtracting, we also multiply all the values by a specific weight - a value from 0 to 1 where 0 is "completely unimportant" and 1 is "extremely important."  So, a value that's less important (like the number of students) will have less impact on the score than an extremely important feature such as percentage of students in computer science or the overall cost of attendance. NOTE: again, weights are determined subjectively based on how relatively important certain features are to ME. Normally, the weights would be determined by a consensus of data scientists, often with the use of research and analysis. In this system, an absolutely ideal college that has a 100 in every "good feature" and a 0 in every "bad" feature will get 500 points: 100\*1+100\*0.6+100\*0.8+100\*0.6+100\*0.9+100\*0.4+100\*0.7-0 = 500
# 3. Instead of absolute deviation, standard deviation/z-score could've been used:
#
#     `toNorm.apply(lambda x: (x-x.mean())/x.std(ddof=0))`.
#
#     However, in this method, the more the value deviates from the mean, the worse. For most features, that would be a good idea, but that would not work with some of the deviation features. For instance, the mean % female in Illinois colleges is 60%, whereas my ideal value is 50%. With the z-score technique, a college with 50% females would get a lower z-score than a college with 60%. So, logically, this feature needs to be minimized (lower score = better), however, there's another issue - a percentage that's too low is bad as well. So, the mean in a lot of cases doesn't correspond to my preferred values. Another example is % computer science students - the mean in the state is 2, so a college with 20% comp sci students will get a high z score as it is far away from the mean. So, again, if this is the case, then high z score for % comp sci students should be good, right? But a college with 97% comp sci students would not be a good fit either. So z-score is not well suited for this project. The only way to calculate deviations is see how much each value deviates not from the mean, but from my preference.

# %%
pd.options.mode.chained_assignment = None #avoid the false warnings
toNorm = collegeInfo.select_dtypes('number')

#standardize directly, maximize: salary 10, salary 6, act, sats, # students, grad rate
#standardize directly, minimize: price, cost, tuition, distance
#standardize deviation, minimize deviation: admission rate, all with % besides federal loan and bachelor's, master's, etc

#1 - calculating deviation
toNorm['Admission rate deviation'] = toNorm['Admission rate'].map(lambda x: abs(x-65))
toNorm['% female deviation'] = toNorm['% female'].map(lambda x: abs(x-50))
toNorm['% Black deviation'] = toNorm['% Black'].map(lambda x: abs(x-5))
toNorm['% White deviation'] = toNorm['% White'].map(lambda x: abs(x-70))
toNorm['% students in computer science deviation'] = toNorm['% students in computer science'].map(lambda x: abs(x-20))
toNorm['% students in math deviation'] = toNorm['% students in math'].map(lambda x: abs(x-10))

#2 - normalizing, calculating score, multipying by weights
normalized=((toNorm-toNorm.min())/(toNorm.max()-toNorm.min()))*100 #Found this method by looking up 'pandas standardize each column', 2nd result
normalized['Score'] = (
            normalized['Salary 10 years after entry'].fillna(0)+ #extremely important - weight is 1
            normalized['Salary 6 years after entry'].fillna(0)*0.6+
            normalized['Cumulative ACT score'].fillna(0)*0.8+
            normalized['SAT Reading'].fillna(0)*0.6+
            normalized['SAT Math'].fillna(0)*0.9+
            normalized['# students'].fillna(0)*0.4+ #many universities have NaN SAT writing, so I removed it
            normalized['Graduation rate'].fillna(0)*0.7-
            
            normalized['Overall annual cost of attendance'].fillna(100)*0.9-
            normalized['In-state tuition'].fillna(100)*0.8-
            normalized['Approximate distance from home (mi)'].fillna(100)*0.6-
            normalized['Admission rate deviation'].fillna(100)*0.5-
            normalized['% Black deviation'].fillna(100)*0.7-
            normalized['% White deviation'].fillna(100)*0.7-
            normalized['% female deviation'].fillna(100)*0.4-
            normalized['% students in computer science deviation'].fillna(100)- #extremely important - weght is 1
            normalized['% students in math deviation'].fillna(100)*0.5
)


#add the word 'normalized' to the columns with 'deviation' in their names. 
#The other columns (aside from Score) will automatically have the word 'normalized' added to them as a suffix while merging, since the orginal collegeInfo df has the same column names. 
normalized.rename(lambda x: x + ' normalized' if 'deviation' in x else x,axis = 1,inplace=True)
normalizedExtended = pd.merge(normalized,collegeInfo,how='left',left_index=True,right_index=True,suffixes=(' normalized','')) 
#could really use any method (not just left) since the goal of this merge is  just to add new columns
with pd.option_context('display.max_columns', None):  #show all columns
    display(normalizedExtended.nlargest(20,columns=['Score']))
# Out:
#                                             Salary 10 years after entry normalized  \
# University of Illinois at Urbana-Champaign                               65.042980
# University of Chicago                                                    74.498567
# Northwestern University                                                  75.787966
# Illinois Institute of Technology                                         75.931232
# University of Illinois at Chicago                                        54.727794
# Lewis University                                                         46.848138
# Loyola University Chicago                                                54.441261
# Bradley University                                                       53.724928
# Illinois State University                                                44.412607
# Illinois Wesleyan University                                             61.604585
# Northern Illinois University                                             42.120344
# University of St Francis                                                 53.008596
# Chamberlain University-Illinois                                          60.601719
# DePaul University                                                        53.295129
# Benedictine University                                                   47.134670
# Roosevelt University                                                     39.398281
# Aurora University                                                        38.108883
# DeVry University-Illinois                                                40.114613
# Saint Xavier University                                                  45.988539
# Dominican University                                                     44.412607
#
#                                             Salary 6 years after entry normalized  \
# University of Illinois at Urbana-Champaign                              62.825279
# University of Chicago                                                   76.208178
# Northwestern University                                                 84.758364
# Illinois Institute of Technology                                        78.996283
# University of Illinois at Chicago                                       48.884758
# Lewis University                                                        50.929368
# Loyola University Chicago                                               54.646840
# Bradley University                                                      55.018587
# Illinois State University                                               48.884758
# Illinois Wesleyan University                                            52.602230
# Northern Illinois University                                            43.680297
# University of St Francis                                                57.249071
# Chamberlain University-Illinois                                        100.000000
# DePaul University                                                       53.531599
# Benedictine University                                                  49.628253
# Roosevelt University                                                    43.680297
# Aurora University                                                       45.167286
# DeVry University-Illinois                                               35.873606
# Saint Xavier University                                                 46.096654
# Dominican University                                                    41.821561
#
#                                             Admission rate normalized  \
# University of Illinois at Urbana-Champaign                  65.777778
# University of Chicago                                        7.682540
# Northwestern University                                      8.962963
# Illinois Institute of Technology                            61.566138
# University of Illinois at Chicago                           79.947090
# Lewis University                                            61.121693
# Loyola University Chicago                                   71.873016
# Bradley University                                          70.698413
# Illinois State University                                   94.370370
# Illinois Wesleyan University                                61.957672
# Northern Illinois University                                57.544974
# University of St Francis                                    49.502646
# Chamberlain University-Illinois                             82.010582
# DePaul University                                           71.460317
# Benedictine University                                      66.486772
# Roosevelt University                                        68.624339
# Aurora University                                           85.883598
# DeVry University-Illinois                                  100.000000
# Saint Xavier University                                     78.253968
# Dominican University                                        67.502646
#
#                                             % female normalized  \
# University of Illinois at Urbana-Champaign            49.753272
# University of Chicago                                 52.360009
# Northwestern University                               52.917829
# Illinois Institute of Technology                      28.867196
# University of Illinois at Chicago                     53.368376
# Lewis University                                      55.588929
# Loyola University Chicago                             70.188801
# Bradley University                                    53.518558
# Illinois State University                             57.004935
# Illinois Wesleyan University                          52.746192
# Northern Illinois University                          54.022742
# University of St Francis                              65.844239
# Chamberlain University-Illinois                       92.898520
# DePaul University                                     55.674748
# Benedictine University                                58.474576
# Roosevelt University                                  67.635700
# Aurora University                                     68.021884
# DeVry University-Illinois                             61.671315
# Saint Xavier University                               68.000429
# Dominican University                                  71.486805
#
#                                             % Asian normalized  \
# University of Illinois at Urbana-Champaign           89.386792
# University of Chicago                                90.471698
# Northwestern University                              81.792453
# Illinois Institute of Technology                     71.132075
# University of Illinois at Chicago                   100.000000
# Lewis University                                     24.150943
# Loyola University Chicago                            59.150943
# Bradley University                                   16.320755
# Illinois State University                             9.952830
# Illinois Wesleyan University                         26.037736
# Northern Illinois University                         26.367925
# University of St Francis                             12.735849
# Chamberlain University-Illinois                      31.698113
# DePaul University                                    46.415094
# Benedictine University                               68.679245
# Roosevelt University                                 26.603774
# Aurora University                                    11.132075
# DeVry University-Illinois                            17.075472
# Saint Xavier University                              14.103774
# Dominican University                                 15.943396
#
#                                             % Black normalized  \
# University of Illinois at Urbana-Champaign            7.839066
# University of Chicago                                 6.722907
# Northwestern University                               7.709280
# Illinois Institute of Technology                      6.696950
# University of Illinois at Chicago                    10.266061
# Lewis University                                      7.203115
# Loyola University Chicago                             7.086308
# Bradley University                                    9.007138
# Illinois State University                            12.083063
# Illinois Wesleyan University                          8.007787
# Northern Illinois University                         21.453602
# University of St Francis                             12.654121
# Chamberlain University-Illinois                      16.651525
# DePaul University                                    10.201168
# Benedictine University                               11.135626
# Roosevelt University                                 19.870214
# Aurora University                                     9.513303
# DeVry University-Illinois                            29.889682
# Saint Xavier University                              15.262816
# Dominican University                                  7.800130
#
#                                             % Hispanic normalized  \
# University of Illinois at Urbana-Champaign                  12.03
# University of Chicago                                       13.68
# Northwestern University                                     12.52
# Illinois Institute of Technology                            16.52
# University of Illinois at Chicago                           34.03
# Lewis University                                            20.75
# Loyola University Chicago                                   16.48
# Bradley University                                          10.37
# Illinois State University                                   11.06
# Illinois Wesleyan University                                 9.43
# Northern Illinois University                                19.00
# University of St Francis                                    19.94
# Chamberlain University-Illinois                             12.66
# DePaul University                                           18.69
# Benedictine University                                      17.50
# Roosevelt University                                        24.44
# Aurora University                                           31.92
# DeVry University-Illinois                                   15.02
# Saint Xavier University                                     39.08
# Dominican University                                        55.62
#
#                                             % White normalized  \
# University of Illinois at Urbana-Champaign           51.352921
# University of Chicago                                45.639299
# Northwestern University                              52.792939
# Illinois Institute of Technology                     42.213448
# University of Illinois at Chicago                    32.888166
# Lewis University                                     68.540239
# Loyola University Chicago                            63.627918
# Bradley University                                   84.461735
# Illinois State University                            84.926257
# Illinois Wesleyan University                         80.792010
# Northern Illinois University                         61.003368
# University of St Francis                             69.747997
# Chamberlain University-Illinois                      66.960864
# DePaul University                                    60.898850
# Benedictine University                               48.705145
# Roosevelt University                                 50.807107
# Aurora University                                    56.091046
# DeVry University-Illinois                            56.509116
# Saint Xavier University                              47.079317
# Dominican University                                 34.258507
#
#                                             % students in computer science normalized  \
# University of Illinois at Urbana-Champaign                                  19.345485
# University of Chicago                                                       19.925435
# Northwestern University                                                     21.830986
# Illinois Institute of Technology                                            70.381110
# University of Illinois at Chicago                                           25.932063
# Lewis University                                                            34.424192
# Loyola University Chicago                                                    7.580779
# Bradley University                                                          16.487158
# Illinois State University                                                   11.557581
# Illinois Wesleyan University                                                 8.202154
# Northern Illinois University                                                15.741508
# University of St Francis                                                     5.012428
# Chamberlain University-Illinois                                              0.000000
# DePaul University                                                           30.447390
# Benedictine University                                                       7.580779
# Roosevelt University                                                        17.564209
# Aurora University                                                            8.202154
# DeVry University-Illinois                                                   67.605634
# Saint Xavier University                                                     17.439934
# Dominican University                                                        11.226181
#
#                                             % students in math normalized  \
# University of Illinois at Urbana-Champaign                      40.300107
# University of Chicago                                          100.000000
# Northwestern University                                         43.729904
# Illinois Institute of Technology                                11.468382
# University of Illinois at Chicago                               10.503751
# Lewis University                                                11.468382
# Loyola University Chicago                                       11.682744
# Bradley University                                               3.215434
# Illinois State University                                       17.470525
# Illinois Wesleyan University                                    26.580922
# Northern Illinois University                                    13.719185
# University of St Francis                                        10.396570
# Chamberlain University-Illinois                                  0.000000
# DePaul University                                               10.289389
# Benedictine University                                           9.110397
# Roosevelt University                                             4.501608
# Aurora University                                                9.110397
# DeVry University-Illinois                                        0.000000
# Saint Xavier University                                          3.001072
# Dominican University                                            11.575563
#
#                                             Cumulative ACT score normalized  \
# University of Illinois at Urbana-Champaign                            68.75
# University of Chicago                                                100.00
# Northwestern University                                              100.00
# Illinois Institute of Technology                                      68.75
# University of Illinois at Chicago                                     37.50
# Lewis University                                                      37.50
# Loyola University Chicago                                             62.50
# Bradley University                                                    50.00
# Illinois State University                                             31.25
# Illinois Wesleyan University                                          56.25
# Northern Illinois University                                          25.00
# University of St Francis                                              31.25
# Chamberlain University-Illinois                                         NaN
# DePaul University                                                       NaN
# Benedictine University                                                31.25
# Roosevelt University                                                  37.50
# Aurora University                                                     18.75
# DeVry University-Illinois                                               NaN
# Saint Xavier University                                               25.00
# Dominican University                                                  25.00
#
#                                             SAT Reading normalized  \
# University of Illinois at Urbana-Champaign               61.089494
# University of Chicago                                   100.000000
# Northwestern University                                  94.163424
# Illinois Institute of Technology                         59.143969
# University of Illinois at Chicago                        28.015564
# Lewis University                                         28.015564
# Loyola University Chicago                                49.416342
# Bradley University                                       41.634241
# Illinois State University                                26.070039
# Illinois Wesleyan University                             49.416342
# Northern Illinois University                             22.178988
# University of St Francis                                 28.015564
# Chamberlain University-Illinois                                NaN
# DePaul University                                              NaN
# Benedictine University                                   21.789883
# Roosevelt University                                     26.070039
# Aurora University                                        18.287938
# DeVry University-Illinois                                      NaN
# Saint Xavier University                                  14.396887
# Dominican University                                     14.396887
#
#                                             SAT Math normalized  \
# University of Illinois at Urbana-Champaign            73.529412
# University of Chicago                                100.000000
# Northwestern University                               95.588235
# Illinois Institute of Technology                      69.117647
# University of Illinois at Chicago                     36.764706
# Lewis University                                      36.764706
# Loyola University Chicago                             48.529412
# Bradley University                                    47.058824
# Illinois State University                             32.352941
# Illinois Wesleyan University                          50.882353
# Northern Illinois University                          29.411765
# University of St Francis                              33.823529
# Chamberlain University-Illinois                             NaN
# DePaul University                                           NaN
# Benedictine University                                30.882353
# Roosevelt University                                  30.882353
# Aurora University                                     26.470588
# DeVry University-Illinois                                   NaN
# Saint Xavier University                               23.529412
# Dominican University                                  23.529412
#
#                                             SAT Writing normalized  \
# University of Illinois at Urbana-Champaign               66.666667
# University of Chicago                                   100.000000
# Northwestern University                                  95.000000
# Illinois Institute of Technology                               NaN
# University of Illinois at Chicago                        31.666667
# Lewis University                                         13.333333
# Loyola University Chicago                                45.000000
# Bradley University                                             NaN
# Illinois State University                                      NaN
# Illinois Wesleyan University                             55.000000
# Northern Illinois University                              8.333333
# University of St Francis                                 10.000000
# Chamberlain University-Illinois                                NaN
# DePaul University                                              NaN
# Benedictine University                                         NaN
# Roosevelt University                                     30.000000
# Aurora University                                        10.666667
# DeVry University-Illinois                                      NaN
# Saint Xavier University                                  20.000000
# Dominican University                                      0.000000
#
#                                             # students normalized  \
# University of Illinois at Urbana-Champaign             100.000000
# University of Chicago                                   19.984224
# Northwestern University                                 25.599951
# Illinois Institute of Technology                         8.831650
# University of Illinois at Chicago                       61.958072
# Lewis University                                        12.754467
# Loyola University Chicago                               35.538970
# Bradley University                                      13.910379
# Illinois State University                               54.704044
# Illinois Wesleyan University                             5.075696
# Northern Illinois University                            38.676011
# University of St Francis                                 4.784442
# Chamberlain University-Illinois                         45.732836
# DePaul University                                       43.284488
# Benedictine University                                   8.127787
# Roosevelt University                                     7.172112
# Aurora University                                       11.926216
# DeVry University-Illinois                               38.621401
# Saint Xavier University                                  8.889293
# Dominican University                                     6.325658
#
#                                             Household income normalized  \
# University of Illinois at Urbana-Champaign                    71.258212
# University of Chicago                                         65.598979
# Northwestern University                                       80.741872
# Illinois Institute of Technology                              64.557094
# University of Illinois at Chicago                             60.121762
# Lewis University                                              76.559689
# Loyola University Chicago                                     68.699527
# Bradley University                                            64.550818
# Illinois State University                                     65.960919
# Illinois Wesleyan University                                  79.193690
# Northern Illinois University                                  67.981924
# University of St Francis                                      70.394159
# Chamberlain University-Illinois                                     NaN
# DePaul University                                             69.835558
# Benedictine University                                        78.181095
# Roosevelt University                                          57.353864
# Aurora University                                             72.341939
# DeVry University-Illinois                                           NaN
# Saint Xavier University                                       54.052471
# Dominican University                                          56.019080
#
#                                             % with a federal loan normalized  \
# University of Illinois at Urbana-Champaign                         38.196345
# University of Chicago                                              11.623071
# Northwestern University                                            22.895918
# Illinois Institute of Technology                                   48.473241
# University of Illinois at Chicago                                  46.601729
# Lewis University                                                   66.575462
# Loyola University Chicago                                          61.551932
# Bradley University                                                 72.441720
# Illinois State University                                          61.256430
# Illinois Wesleyan University                                       68.961366
# Northern Illinois University                                       69.377257
# University of St Francis                                           76.250410
# Chamberlain University-Illinois                                    67.954471
# DePaul University                                                  60.063478
# Benedictine University                                             70.657765
# Roosevelt University                                               70.044872
# Aurora University                                                  72.824778
# DeVry University-Illinois                                          82.948451
# Saint Xavier University                                            90.467331
# Dominican University                                               76.677246
#
#                                             Net price for $48001-75000 household income normalized  \
# University of Illinois at Urbana-Champaign                                          69.205411
# University of Chicago                                                                     NaN
# Northwestern University                                                                   NaN
# Illinois Institute of Technology                                                          NaN
# University of Illinois at Chicago                                                   55.439354
# Lewis University                                                                          NaN
# Loyola University Chicago                                                                 NaN
# Bradley University                                                                        NaN
# Illinois State University                                                           90.223940
# Illinois Wesleyan University                                                              NaN
# Northern Illinois University                                                       100.000000
# University of St Francis                                                                  NaN
# Chamberlain University-Illinois                                                           NaN
# DePaul University                                                                         NaN
# Benedictine University                                                                    NaN
# Roosevelt University                                                                      NaN
# Aurora University                                                                         NaN
# DeVry University-Illinois                                                                 NaN
# Saint Xavier University                                                                   NaN
# Dominican University                                                                      NaN
#
#                                             Net price for $75001-110000 household income normalized  \
# University of Illinois at Urbana-Champaign                                          91.002985
# University of Chicago                                                                     NaN
# Northwestern University                                                                   NaN
# Illinois Institute of Technology                                                          NaN
# University of Illinois at Chicago                                                   78.049936
# Lewis University                                                                          NaN
# Loyola University Chicago                                                                 NaN
# Bradley University                                                                        NaN
# Illinois State University                                                           99.355664
# Illinois Wesleyan University                                                              NaN
# Northern Illinois University                                                       100.000000
# University of St Francis                                                                  NaN
# Chamberlain University-Illinois                                                           NaN
# DePaul University                                                                         NaN
# Benedictine University                                                                    NaN
# Roosevelt University                                                                      NaN
# Aurora University                                                                         NaN
# DeVry University-Illinois                                                                 NaN
# Saint Xavier University                                                                   NaN
# Dominican University                                                                      NaN
#
#                                             Overall annual cost of attendance normalized  \
# University of Illinois at Urbana-Champaign                                     32.226362
# University of Chicago                                                         100.000000
# Northwestern University                                                        95.880406
# Illinois Institute of Technology                                               76.807055
# University of Illinois at Chicago                                              25.067918
# Lewis University                                                               46.869851
# Loyola University Chicago                                                      72.628079
# Bradley University                                                             56.308546
# Illinois State University                                                      30.514690
# Illinois Wesleyan University                                                   75.871795
# Northern Illinois University                                                   35.435935
# University of St Francis                                                       47.402800
# Chamberlain University-Illinois                                                31.129288
# DePaul University                                                              68.385267
# Benedictine University                                                         53.459717
# Roosevelt University                                                           52.147385
# Aurora University                                                              39.007734
# DeVry University-Illinois                                                      37.790413
# Saint Xavier University                                                        47.770965
# Dominican University                                                           48.609730
#
#                                             In-state tuition normalized  \
# University of Illinois at Urbana-Champaign                    21.643567
# University of Chicago                                        100.000000
# Northwestern University                                       93.347986
# Illinois Institute of Technology                              80.774191
# University of Illinois at Chicago                             19.227625
# Lewis University                                              53.170696
# Loyola University Chicago                                     74.238433
# Bradley University                                            55.550308
# Illinois State University                                     20.593631
# Illinois Wesleyan University                                  80.756026
# Northern Illinois University                                  20.777098
# University of St Francis                                      52.934552
# Chamberlain University-Illinois                               29.419992
# DePaul University                                             66.839839
# Benedictine University                                        56.513052
# Roosevelt University                                          48.415106
# Aurora University                                             38.293582
# DeVry University-Illinois                                     26.030408
# Saint Xavier University                                       55.768288
# Dominican University                                          54.958130
#
#                                             Out-of-state tuition normalized  \
# University of Illinois at Urbana-Champaign                        48.626018
# University of Chicago                                            100.000000
# Northwestern University                                           92.918335
# Illinois Institute of Technology                                  79.532401
# University of Illinois at Chicago                                 39.567984
# Lewis University                                                  50.146004
# Loyola University Chicago                                         72.574501
# Bradley University                                                52.679314
# Illinois State University                                         37.750189
# Illinois Wesleyan University                                      79.513063
# Northern Illinois University                                      15.660111
# University of St Francis                                          49.894607
# Chamberlain University-Illinois                                   24.861248
# DePaul University                                                 64.698033
# Benedictine University                                            53.704241
# Roosevelt University                                              45.083251
# Aurora University                                                 34.307981
# DeVry University-Illinois                                         21.252732
# Saint Xavier University                                           52.911373
# Dominican University                                              52.048887
#
#                                             Graduation rate normalized  \
# University of Illinois at Urbana-Champaign                   85.526316
# University of Chicago                                        98.684211
# Northwestern University                                     100.000000
# Illinois Institute of Technology                             69.736842
# University of Illinois at Chicago                            52.631579
# Lewis University                                             59.210526
# Loyola University Chicago                                    72.368421
# Bradley University                                           77.631579
# Illinois State University                                    65.789474
# Illinois Wesleyan University                                 78.947368
# Northern Illinois University                                 35.526316
# University of St Francis                                     56.578947
# Chamberlain University-Illinois                              40.789474
# DePaul University                                            69.736842
# Benedictine University                                       36.842105
# Roosevelt University                                         26.315789
# Aurora University                                            46.052632
# DeVry University-Illinois                                     9.210526
# Saint Xavier University                                      50.000000
# Dominican University                                         55.263158
#
#                                             Average amount of aid awarded normalized  \
# University of Illinois at Urbana-Champaign                                 25.425639
# University of Chicago                                                      93.537480
# Northwestern University                                                   100.000000
# Illinois Institute of Technology                                           74.255431
# University of Illinois at Chicago                                          21.881445
# Lewis University                                                           41.324157
# Loyola University Chicago                                                  45.482231
# Bradley University                                                         39.472927
# Illinois State University                                                  14.020910
# Illinois Wesleyan University                                               56.815021
# Northern Illinois University                                               14.948923
# University of St Francis                                                   41.424872
# Chamberlain University-Illinois                                            11.615750
# DePaul University                                                          48.887344
# Benedictine University                                                     36.367560
# Roosevelt University                                                       40.345787
# Aurora University                                                          30.176011
# DeVry University-Illinois                                                   5.764712
# Saint Xavier University                                                    52.201333
# Dominican University                                                       46.189631
#
#                                             % receiving Doctor's normalized  \
# University of Illinois at Urbana-Champaign                        59.379310
# University of Chicago                                             98.482759
# Northwestern University                                           87.448276
# Illinois Institute of Technology                                  88.689655
# University of Illinois at Chicago                                100.000000
# Lewis University                                                   4.482759
# Loyola University Chicago                                         72.827586
# Bradley University                                                14.000000
# Illinois State University                                          6.620690
# Illinois Wesleyan University                                       0.000000
# Northern Illinois University                                      32.344828
# University of St Francis                                          26.827586
# Chamberlain University-Illinois                                   14.758621
# DePaul University                                                 32.275862
# Benedictine University                                            10.620690
# Roosevelt University                                              41.862069
# Aurora University                                                  7.310345
# DeVry University-Illinois                                          0.000000
# Saint Xavier University                                            0.000000
# Dominican University                                               1.379310
#
#                                             % receiving Master's normalized  \
# University of Illinois at Urbana-Champaign                        44.282093
# University of Chicago                                             87.028478
# Northwestern University                                           88.012524
# Illinois Institute of Technology                                  97.748621
# University of Illinois at Chicago                                 46.682570
# Lewis University                                                  48.531385
# Loyola University Chicago                                         47.860444
# Bradley University                                                30.788728
# Illinois State University                                         19.323095
# Illinois Wesleyan University                                       0.000000
# Northern Illinois University                                      41.165946
# University of St Francis                                          80.423438
# Chamberlain University-Illinois                                   38.541822
# DePaul University                                                 58.953332
# Benedictine University                                            77.262562
# Roosevelt University                                              67.287908
# Aurora University                                                 59.296258
# DeVry University-Illinois                                         59.624273
# Saint Xavier University                                           46.622931
# Dominican University                                              67.496645
#
#                                             % receiving Bachelor's normalized  \
# University of Illinois at Urbana-Champaign                          51.147666
# University of Chicago                                                7.357817
# Northwestern University                                              8.556491
# Illinois Institute of Technology                                     0.000000
# University of Illinois at Chicago                                   41.583780
# Lewis University                                                    57.447080
# Loyola University Chicago                                           42.769702
# Bradley University                                                  71.078806
# Illinois State University                                           82.249426
# Illinois Wesleyan University                                       100.000000
# Northern Illinois University                                        58.811528
# University of St Francis                                            26.256057
# Chamberlain University-Illinois                                     64.307575
# DePaul University                                                   43.611324
# Benedictine University                                              31.956134
# Roosevelt University                                                34.697781
# Aurora University                                                   47.934200
# DeVry University-Illinois                                           30.311145
# Saint Xavier University                                             60.124968
# Dominican University                                                42.030094
#
#                                             % receiving Associate's normalized  \
# University of Illinois at Urbana-Champaign                            0.000000
# University of Chicago                                                 0.000000
# Northwestern University                                               0.000000
# Illinois Institute of Technology                                      0.000000
# University of Illinois at Chicago                                     0.000000
# Lewis University                                                      0.524762
# Loyola University Chicago                                             7.248278
# Bradley University                                                    0.000000
# Illinois State University                                             0.000000
# Illinois Wesleyan University                                          0.000000
# Northern Illinois University                                          0.000000
# University of St Francis                                              0.000000
# Chamberlain University-Illinois                                       0.000000
# DePaul University                                                     0.000000
# Benedictine University                                                0.000000
# Roosevelt University                                                  0.000000
# Aurora University                                                     0.000000
# DeVry University-Illinois                                            48.081338
# Saint Xavier University                                               0.000000
# Dominican University                                                  0.000000
#
#                                             Approximate distance from home (mi) normalized  \
# University of Illinois at Urbana-Champaign                                       91.384102
# University of Chicago                                                            14.737354
# Northwestern University                                                           6.941356
# Illinois Institute of Technology                                                 12.632018
# University of Illinois at Chicago                                                10.839355
# Lewis University                                                                 18.899389
# Loyola University Chicago                                                         7.830739
# Bradley University                                                               85.985270
# Illinois State University                                                        80.301556
# Illinois Wesleyan University                                                     81.163146
# Northern Illinois University                                                     27.744580
# University of St Francis                                                         22.804336
# Chamberlain University-Illinois                                                   3.258755
# DePaul University                                                                11.131184
# Benedictine University                                                           11.388271
# Roosevelt University                                                             11.423013
# Aurora University                                                                17.871039
# DeVry University-Illinois                                                         7.789049
# Saint Xavier University                                                          15.508616
# Dominican University                                                              5.628127
#
# ...
# Lewis University                                                      39946.0
# Loyola University Chicago                                             57297.0
# Bradley University                                                    46304.0
# Illinois State University                                             28929.0
# Illinois Wesleyan University                                          59482.0
# Northern Illinois University                                          32244.0
# University of St Francis                                              40305.0
# Chamberlain University-Illinois                                       29343.0
# DePaul University                                                     54439.0
# Benedictine University                                                44385.0
# Roosevelt University                                                  43501.0
# Aurora University                                                     34650.0
# DeVry University-Illinois                                             33830.0
# Saint Xavier University                                               40553.0
# Dominican University                                                  41118.0
#
#                                             In-state tuition  \
# University of Illinois at Urbana-Champaign           15094.0
# University of Chicago                                58230.0
# Northwestern University                              54568.0
# Illinois Institute of Technology                     47646.0
# University of Illinois at Chicago                    13764.0
# Lewis University                                     32450.0
# Loyola University Chicago                            44048.0
# Bradley University                                   33760.0
# Illinois State University                            14516.0
# Illinois Wesleyan University                         47636.0
# Northern Illinois University                         14617.0
# University of St Francis                             32320.0
# Chamberlain University-Illinois                      19375.0
# DePaul University                                    39975.0
# Benedictine University                               34290.0
# Roosevelt University                                 29832.0
# Aurora University                                    24260.0
# DeVry University-Illinois                            17509.0
# Saint Xavier University                              33880.0
# Dominican University                                 33434.0
#
#                                             Out-of-state tuition  \
# University of Illinois at Urbana-Champaign               31664.0
# University of Chicago                                    58230.0
# Northwestern University                                  54568.0
# Illinois Institute of Technology                         47646.0
# University of Illinois at Chicago                        26980.0
# Lewis University                                         32450.0
# Loyola University Chicago                                44048.0
# Bradley University                                       33760.0
# Illinois State University                                26040.0
# Illinois Wesleyan University                             47636.0
# Northern Illinois University                             14617.0
# University of St Francis                                 32320.0
# Chamberlain University-Illinois                          19375.0
# DePaul University                                        39975.0
# Benedictine University                                   34290.0
# Roosevelt University                                     29832.0
# Aurora University                                        24260.0
# DeVry University-Illinois                                17509.0
# Saint Xavier University                                  33880.0
# Dominican University                                     33434.0
#
#                                                              Address  \
# University of Illinois at Urbana-Champaign         601 E John Street
# University of Chicago                               5801 S Ellis Ave
# Northwestern University                                 633 Clark St
# Illinois Institute of Technology                 10 West 35th Street
# University of Illinois at Chicago                       601 S Morgan
# Lewis University                              One University Parkway
# Loyola University Chicago                        1032 W. Sheridan Rd
# Bradley University                                1501 W Bradley Ave
# Illinois State University                   North and School Streets
# Illinois Wesleyan University                          1312 N Park St
# Northern Illinois University                    1425 W. Lincoln Hwy.
# University of St Francis                             500 N Wilcox St
# Chamberlain University-Illinois                   1221 N. Swift Road
# DePaul University                                   1 E Jackson Blvd
# Benedictine University                               5700 College Rd
# Roosevelt University                              430 S Michigan Ave
# Aurora University                                347 S Gladstone Ave
# DeVry University-Illinois                      3300 N. Campbell Ave.
# Saint Xavier University                              3700 W 103rd St
# Dominican University                          7900 W Division Street
#
#                                             Graduation rate  \
# University of Illinois at Urbana-Champaign             84.0
# University of Chicago                                  94.0
# Northwestern University                                95.0
# Illinois Institute of Technology                       72.0
# University of Illinois at Chicago                      59.0
# Lewis University                                       64.0
# Loyola University Chicago                              74.0
# Bradley University                                     78.0
# Illinois State University                              69.0
# Illinois Wesleyan University                           79.0
# Northern Illinois University                           46.0
# University of St Francis                               62.0
# Chamberlain University-Illinois                        50.0
# DePaul University                                      72.0
# Benedictine University                                 47.0
# Roosevelt University                                   39.0
# Aurora University                                      54.0
# DeVry University-Illinois                              26.0
# Saint Xavier University                                57.0
# Dominican University                                   61.0
#
#                                             Average amount of aid awarded  \
# University of Illinois at Urbana-Champaign                        14328.0
# University of Chicago                                             42732.0
# Northwestern University                                           45427.0
# Illinois Institute of Technology                                  34691.0
# University of Illinois at Chicago                                 12850.0
# Lewis University                                                  20958.0
# Loyola University Chicago                                         22692.0
# Bradley University                                                20186.0
# Illinois State University                                          9572.0
# Illinois Wesleyan University                                      27418.0
# Northern Illinois University                                       9959.0
# University of St Francis                                          21000.0
# Chamberlain University-Illinois                                    8569.0
# DePaul University                                                 24112.0
# Benedictine University                                            18891.0
# Roosevelt University                                              20550.0
# Aurora University                                                 16309.0
# DeVry University-Illinois                                          6129.0
# Saint Xavier University                                           25494.0
# Dominican University                                              22987.0
#
#                                             % receiving Doctor's  \
# University of Illinois at Urbana-Champaign                  8.61
# University of Chicago                                      14.28
# Northwestern University                                    12.68
# Illinois Institute of Technology                           12.86
# University of Illinois at Chicago                          14.50
# Lewis University                                            0.65
# Loyola University Chicago                                  10.56
# Bradley University                                          2.03
# Illinois State University                                   0.96
# Illinois Wesleyan University                                0.00
# Northern Illinois University                                4.69
# University of St Francis                                    3.89
# Chamberlain University-Illinois                             2.14
# DePaul University                                           4.68
# Benedictine University                                      1.54
# Roosevelt University                                        6.07
# Aurora University                                           1.06
# DeVry University-Illinois                                   0.00
# Saint Xavier University                                     0.00
# Dominican University                                        0.20
#
#                                             % receiving Master's  \
# University of Illinois at Urbana-Champaign                 29.70
# University of Chicago                                      58.37
# Northwestern University                                    59.03
# Illinois Institute of Technology                           65.56
# University of Illinois at Chicago                          31.31
# Lewis University                                           32.55
# Loyola University Chicago                                  32.10
# Bradley University                                         20.65
# Illinois State University                                  12.96
# Illinois Wesleyan University                                0.00
# Northern Illinois University                               27.61
# University of St Francis                                   53.94
# Chamberlain University-Illinois                            25.85
# DePaul University                                          39.54
# Benedictine University                                     51.82
# Roosevelt University                                       45.13
# Aurora University                                          39.77
# DeVry University-Illinois                                  39.99
# Saint Xavier University                                    31.27
# Dominican University                                       45.27
#
#                                             % receiving Bachelor's  \
# University of Illinois at Urbana-Champaign                   61.69
# University of Chicago                                        27.35
# Northwestern University                                      28.29
# Illinois Institute of Technology                             21.58
# University of Illinois at Chicago                            54.19
# Lewis University                                             66.63
# Loyola University Chicago                                    55.12
# Bradley University                                           77.32
# Illinois State University                                    86.08
# Illinois Wesleyan University                                100.00
# Northern Illinois University                                 67.70
# University of St Francis                                     42.17
# Chamberlain University-Illinois                              72.01
# DePaul University                                            55.78
# Benedictine University                                       46.64
# Roosevelt University                                         48.79
# Aurora University                                            59.17
# DeVry University-Illinois                                    45.35
# Saint Xavier University                                      68.73
# Dominican University                                         54.54
#
#                                             % receiving Associate's  \
# University of Illinois at Urbana-Champaign                     0.00
# University of Chicago                                          0.00
# Northwestern University                                        0.00
# Illinois Institute of Technology                               0.00
# University of Illinois at Chicago                              0.00
# Lewis University                                               0.16
# Loyola University Chicago                                      2.21
# Bradley University                                             0.00
# Illinois State University                                      0.00
# Illinois Wesleyan University                                   0.00
# Northern Illinois University                                   0.00
# University of St Francis                                       0.00
# Chamberlain University-Illinois                                0.00
# DePaul University                                              0.00
# Benedictine University                                         0.00
# Roosevelt University                                           0.00
# Aurora University                                              0.00
# DeVry University-Illinois                                     14.66
# Saint Xavier University                                        0.00
# Dominican University                                           0.00
#
#                                             Approximate distance from home (mi)
# University of Illinois at Urbana-Champaign                               134.89
# University of Chicago                                                     24.58
# Northwestern University                                                   13.36
# Illinois Institute of Technology                                          21.55
# University of Illinois at Chicago                                         18.97
# Lewis University                                                          30.57
# Loyola University Chicago                                                 14.64
# Bradley University                                                       127.12
# Illinois State University                                                118.94
# Illinois Wesleyan University                                             120.18
# Northern Illinois University                                              43.30
# University of St Francis                                                  36.19
# Chamberlain University-Illinois                                            8.06
# DePaul University                                                         19.39
# Benedictine University                                                    19.76
# Roosevelt University                                                      19.81
# Aurora University                                                         29.09
# DeVry University-Illinois                                                 14.58
# Saint Xavier University                                                   25.69
# Dominican University                                                      11.47

# %%
#another custom subjective scoring system
#This one is more clear-cut (did not meet condition = no points), whereas
#the other one is more fluid - the more you fit the perfect criteria, the more points you get. 
#For instance, if the grad rate of a college is 84 (just one point below the threshold) you get no points for that feature, 
#while in the first one you would get, say, 90/100 points. 
#So, this system is stricter, and overall slightly worse in my opinion (reasons are explained in the next cell)
def score(colSeries):
    score = 0
    if not (isinstance(colSeries['Religious affiliation'],str)): #non-religious is a big plus
        score += 100*0.75
    if (colSeries['Salary 10 years after entry'] >= 60000): #or (math.isnan(colSeries['Salary 10 years after entry'])):
        score += 100*0.4 #add 100 for qualifying, 0.4 is priority on a 0-1 scale
    if (colSeries['Salary 6 years after entry'] >= 40000):
        score += 100*0.6
    if (colSeries['Graduation rate'] >= 85):
        score += 100*0.7
    if ((colSeries['Admission rate'] < 80) and (colSeries['Admission rate'] >= 20)):
        score += 100*0.5
    if (colSeries['SAT Math'] >= 650): #can add other SAT's and ACT
        score += 100*0.7
    if (colSeries['% female'] <= 65):
        score += 100*0.5
    if (colSeries['% Black'] < 10):
        score += 100*0.65
    if ((colSeries['% White'] < 90) and (colSeries['% White'] >= 30)):
        score += 100*0.65
    if (colSeries['% students in computer science'] >= 5):
        score += 100*0.8
    if (colSeries['% students in math'] >= 2.5):
        score += 100*0.5
    if (colSeries['# students'] >= 5000):
        score += 100*0.4
    if (colSeries['Overall annual cost of attendance'] <= 33000):
        score += 100*0.85
    if (colSeries['In-state tuition'] <= 17000):
        score += 100*0.8
    if (colSeries['Approximate distance from home (mi)'] <= 80):
        score += 100*0.6
    return score
collegeInfo['Score'] = collegeInfo.apply(score,axis=1)
bestScore = collegeInfo.nlargest(columns=['Score'],n=20) #out of 940 points
chosen = collegeInfo.loc[['Bradley University','DePaul University','Illinois Institute of Technology',
        'Illinois State University','Lake Forest College','Lewis University','Northwestern University',
        'Rockford University','University of Chicago','University of Illinois at Chicago','University of Illinois at Urbana-Champaign']] #loyolo, ttic?
    #manually chosen from the filtered dataset

#[[]] ensures that no columns get merged, only rows. Columns are the same in both dataframes - no need to duplicate them
chosenAndScore = pd.merge(bestScore, chosen[[]], how='inner', right_index=True,left_index=True) #overlap between chosen and top 20 scores
chosenAndScore #the best of the best. These colleges are also the top 5 according to the first scoring system
# Out:
#                                            Religious affiliation  \
# University of Illinois at Urbana-Champaign                   NaN
# Northwestern University                                      NaN
# University of Chicago                                        NaN
# Illinois Institute of Technology                             NaN
# University of Illinois at Chicago                            NaN
#
#                                             Salary 10 years after entry  \
# University of Illinois at Urbana-Champaign                      61500.0
# Northwestern University                                         69000.0
# University of Chicago                                           68100.0
# Illinois Institute of Technology                                69100.0
# University of Illinois at Chicago                               54300.0
#
#                                             Salary 6 years after entry  \
# University of Illinois at Urbana-Champaign                     47100.0
# Northwestern University                                        58900.0
# University of Chicago                                          54300.0
# Illinois Institute of Technology                               55800.0
# University of Illinois at Chicago                              39600.0
#
#                                             Admission rate  % female  % Asian  \
# University of Illinois at Urbana-Champaign           62.16     49.48    18.95
# Northwestern University                               8.47     52.43    17.34
# University of Chicago                                 7.26     51.91    19.18
# Illinois Institute of Technology                     58.18     30.01    15.08
# University of Illinois at Chicago                    75.55     52.85    21.20
#
#                                             % Black  % Hispanic  % White  \
# University of Illinois at Urbana-Champaign     6.04       12.03    44.22
# Northwestern University                        5.94       12.52    45.46
# University of Chicago                          5.18       13.68    39.30
# Illinois Institute of Technology               5.16       16.52    36.35
# University of Illinois at Chicago              7.91       34.03    28.32
#
#                                             % students in computer science  \
# University of Illinois at Urbana-Champaign                            4.67
# Northwestern University                                               5.27
# University of Chicago                                                 4.81
# Illinois Institute of Technology                                     16.99
# University of Illinois at Chicago                                     6.26
#
#                                             ...  Out-of-state tuition  \
# University of Illinois at Urbana-Champaign  ...               31664.0
# Northwestern University                     ...               54568.0
# University of Chicago                       ...               58230.0
# Illinois Institute of Technology            ...               47646.0
# University of Illinois at Chicago           ...               26980.0
#
#                                                         Address  \
# University of Illinois at Urbana-Champaign    601 E John Street
# Northwestern University                            633 Clark St
# University of Chicago                          5801 S Ellis Ave
# Illinois Institute of Technology            10 West 35th Street
# University of Illinois at Chicago                  601 S Morgan
#
#                                             Graduation rate  \
# University of Illinois at Urbana-Champaign             84.0
# Northwestern University                                95.0
# University of Chicago                                  94.0
# Illinois Institute of Technology                       72.0
# University of Illinois at Chicago                      59.0
#
#                                             Average amount of aid awarded  \
# University of Illinois at Urbana-Champaign                        14328.0
# Northwestern University                                           45427.0
# University of Chicago                                             42732.0
# Illinois Institute of Technology                                  34691.0
# University of Illinois at Chicago                                 12850.0
#
#                                             % receiving Doctor's  \
# University of Illinois at Urbana-Champaign                  8.61
# Northwestern University                                    12.68
# University of Chicago                                      14.28
# Illinois Institute of Technology                           12.86
# University of Illinois at Chicago                          14.50
#
#                                            % receiving Master's  \
# University of Illinois at Urbana-Champaign                29.70
# Northwestern University                                   59.03
# University of Chicago                                     58.37
# Illinois Institute of Technology                          65.56
# University of Illinois at Chicago                         31.31
#
#                                            % receiving Bachelor's  \
# University of Illinois at Urbana-Champaign                  61.69
# Northwestern University                                     28.29
# University of Chicago                                       27.35
# Illinois Institute of Technology                            21.58
# University of Illinois at Chicago                           54.19
#
#                                            % receiving Associate's  \
# University of Illinois at Urbana-Champaign                     0.0
# Northwestern University                                        0.0
# University of Chicago                                          0.0
# Illinois Institute of Technology                               0.0
# University of Illinois at Chicago                              0.0
#
#                                            Approximate distance from home (mi)  \
# University of Illinois at Urbana-Champaign                              134.89
# Northwestern University                                                  13.36
# University of Chicago                                                    24.58
# Illinois Institute of Technology                                         21.55
# University of Illinois at Chicago                                        18.97
#
#                                             Score
# University of Illinois at Urbana-Champaign  730.0
# Northwestern University                     725.0
# University of Chicago                       645.0
# Illinois Institute of Technology            615.0
# University of Illinois at Chicago           585.0
#
# [5 rows x 40 columns]

# %%
chosenNotScore = chosen[~chosen.isin(bestScore)].dropna(how='all') #those that I chose, but are not in top 20 scores
#chosenNotScore.iloc[0] #Bradley University - 8th in the first system. Reasons for not being in the top 20: low salary, far away, expensive, too few students in comp sci and math, low math SAT, small student body, somewhat low grad rate
#chosenNotScore.iloc[1] #DePaul - 14th in the first system. Reasons: Catholic, low salary, few students in math, no info about sat, expensive, low grad rate
#chosenNotScore.iloc[2] #Illinois State - 9th. Low salary, high admission rate, few students in comp sci and math, low SAT, low grad rate, far away
#chosenNotScore.iloc[3] #Lake Forest - not in top 20 in the first system. Low salary, few students in comp sci, no SAT info, small student body, expensive, low grad rate
#chosenNotScore.iloc[4] #Lewis - 6th. Catholic, low salary, few students in math, low SAT, small student body, expensive, low grad rate
#chosenNotScore.iloc[5] #Rockford - not in top 20 in the first system. Low salary, few students in comp sci and math, low SAT math, very small student body, expensive

scoreNotChosen = bestScore[~bestScore.isin(chosen)].dropna(how='all') #those that are in top 20, but are not chosen
scoreNotChosen[scoreNotChosen['Ownership'] != 'Public'].iloc[0] #All are public universities, aside from Fox College, which only offers associate's degrees. 
#I guess this scoring system was too focused on cost, and cared less about the quality of education. 
#The first scoring system is better - it provides a more balanced perspective.
# Out:
# Religious affiliation                                          NaN
# Salary 10 years after entry                                  33500
# Salary 6 years after entry                                   29800
# Admission rate                                               69.16
# % female                                                     83.05
# % Asian                                                       5.64
# % Black                                                        8.8
# % Hispanic                                                   22.12
# % White                                                      59.14
# % students in computer science                                   0
# % students in math                                               0
# Cumulative ACT score                                           NaN
# SAT Reading                                                    NaN
# SAT Math                                                       NaN
# SAT Writing                                                    NaN
# Aliases                                                        NaN
# City                                                  Bedford Park
# Level of institution                                        2-year
# Locale                                                Large Suburb
# Ownership                                              Proprietary
# Website                                         www.foxcollege.edu
# State                                                     Illinois
# ZIP                                                          60638
# # students                                                     443
# Household income                                             59508
# % with a federal loan                                        87.76
# Net price for $48001-75000 household income                    NaN
# Net price for $75001-110000 household income                   NaN
# Overall annual cost of attendance                            19914
# In-state tuition                                             15220
# Out-of-state tuition                                         15220
# Address                                             6640 S. Cicero
# Graduation rate                                                 76
# Average amount of aid awarded                                 6149
# % receiving Doctor's                                           NaN
# % receiving Master's                                           NaN
# % receiving Bachelor's                                         NaN
# % receiving Associate's                                        NaN
# Approximate distance from home (mi)                           21.3
# Score                                                          480
# Name: Fox College, dtype: object

# %% [markdown]
# IN CONCLUSION:
# Top colleges are UIUC, Northwestern, U of C, IIT, UIC.
# The cells below are just exercises or failed pieces of code that I decided to leave just for reference. There is another notebook that uses the same algorithms, but it is not limited to Illinois. There is also another notebook which uses machine learning to predict what state a university is in based on its characteristics.

# %%
#search engine
def searchByName(name):
    results = pd.DataFrame(columns=collegeInfo.columns) #empty df
    
    alNoNANs = collegeInfo.dropna(subset=['Aliases'])['Aliases']
    results = results.append(alNoNANs[alNoNANs.str.contains(name,case=False)])
    
    ciNoNANs = collegeInfo.dropna(subset=['City'])['City']
    results = results.append(ciNoNANs[ciNoNANs.str.contains(name,case=False)])
    
    ind = collegeInfo.index
    results = results.append(collegeInfo[ind.str.contains(name,case=False)])

    if results.empty:
        return 'Nothing found, try another search'
    
    return results.drop_duplicates().drop(['Aliases','City'])

results = searchByName('University of Illinois') #can use regex
display(results)


def searchGoogle():
    inp = pyip.inputYesNo('Would you like to search for these colleges on the web?')
    if inp == 'yes':
        if len(results.index) < 6:
            for college in results.index:
                webbrowser.open_new_tab('https://www.google.com/search?q={}'.format(college))
        else:
            print('Sorry, too many colleges. Chrome will crash :)')
    else:
        print('OK')
if not isinstance(results,str):
    searchGoogle()
# Out:
#                                            Religious affiliation  \
# University of Illinois at Chicago                            NaN
# University of Illinois at Urbana-Champaign                   NaN
#
#                                             Salary 10 years after entry  \
# University of Illinois at Chicago                               54300.0
# University of Illinois at Urbana-Champaign                      61500.0
#
#                                             Salary 6 years after entry  \
# University of Illinois at Chicago                              39600.0
# University of Illinois at Urbana-Champaign                     47100.0
#
#                                             Admission rate  % female  % Asian  \
# University of Illinois at Chicago                    75.55     52.85    21.20
# University of Illinois at Urbana-Champaign           62.16     49.48    18.95
#
#                                             % Black  % Hispanic  % White  \
# University of Illinois at Chicago              7.91       34.03    28.32
# University of Illinois at Urbana-Champaign     6.04       12.03    44.22
#
#                                             % students in computer science  \
# University of Illinois at Chicago                                     6.26
# University of Illinois at Urbana-Champaign                            4.67
#
#                                             ...  Graduation rate  \
# University of Illinois at Chicago           ...             59.0
# University of Illinois at Urbana-Champaign  ...             84.0
#
#                                             Average amount of aid awarded  \
# University of Illinois at Chicago                                 12850.0
# University of Illinois at Urbana-Champaign                        14328.0
#
#                                             % receiving Doctor's  \
# University of Illinois at Chicago                          14.50
# University of Illinois at Urbana-Champaign                  8.61
#
#                                             % receiving Master's  \
# University of Illinois at Chicago                          31.31
# University of Illinois at Urbana-Champaign                 29.70
#
#                                             % receiving Bachelor's  \
# University of Illinois at Chicago                            54.19
# University of Illinois at Urbana-Champaign                   61.69
#
#                                            % receiving Associate's  \
# University of Illinois at Chicago                              0.0
# University of Illinois at Urbana-Champaign                     0.0
#
#                                            Approximate distance from home (mi)  \
# University of Illinois at Chicago                                        18.97
# University of Illinois at Urbana-Champaign                              134.89
#
#                                             Score  \
# University of Illinois at Chicago           585.0
# University of Illinois at Urbana-Champaign  730.0
#
#                                            University of Illinois at Chicago  \
# University of Illinois at Chicago                                        NaN
# University of Illinois at Urbana-Champaign                               NaN
#
#                                            University of Illinois at Urbana-Champaign
# University of Illinois at Chicago                                                 NaN
# University of Illinois at Urbana-Champaign                                        NaN
#
# [2 rows x 42 columns]
# Would you like to search for these colleges on the web?
#  n
# OK

# %%
#open college's websites after looking them up
def open_web(college):
    if len(searchByName(college).index) == 0:
        return 'No such college, try another search'
    elif 0 < len(searchByName(college).index) < 6:
        for url in searchByName(college)['Website'].values:
            webbrowser.open_new_tab('https://'+url)
        return searchByName(college)
    else:
        return 'College name is too ambiguous, try a narrower search'
#open_web('University of Illinois')

# %%
#This was supposed to scrape usnews for compsci rankings, but for some reason it results in a timeout error.

from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
def simple_get(url):
    #Attempts to get the content at url by making an HTTP GET request.
    #If the content-type of response is some kind of HTML/XML, return the
    #text content, otherwise return None.
    try:
        with closing(requests.get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None
    except RequestException as e:
        print('Error during requests to {0} : {1}'.format(url, str(e)))
        return None
def is_good_response(resp):
    #Returns True if the response seems to be HTML, False otherwise.
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 and content_type is not None and content_type.find('html') > -1)
def compSciRank(college):
    #college = '-'.join(college.split())
    raw_html = simple_get('https://www.usnews.com/best-graduate-schools/top-science-schools/computer-science-rankings')
    soup = BeautifulSoup(raw_html,'html.parser')
    return soup.find_all('a')

# %%
#USING THE UNOFFICIAL WRAPPER FOR THE COLLEGESCORECARD API - PyScorecard.
#Use this cautiosly - every now and then it randomly results in an error (that goes away without any apparent fix) 
#and some filters (such as by state) are inaccessible
#It is more readable but less reliable than the code above
"""
from PyScorecard import PyScorecard
import pandas as pd

scorecard = PyScorecard()
scorecard.set_api_key('nyiNevdtUIEMrkovbB6bYPDsdi8V4rRBSEzXtN9s')
scorecard.set_year('latest')

scorecard.add_filter("school.men_only","=","0")
scorecard.add_filter("school.women_only","=","0")
scorecard.add_filter("school.online_only","=","0")
scorecard.add_filter("school.operating","=","1")
scorecard.add_filter("school.region_id","=","3") #3 is midwest
#scorecard.add_filter("school.state","=","IL") #doesn't work for some reason - maybe because it's a string

scorecard.add_fields([
    "school.name","school.alias","school.city","school.state","school.zip","school.ownership_peps","school.school_url","school.locale","school.institutional_characteristics.level",
    "admissions.admission_rate.overall","admissions.sat_scores.midpoint.critical_reading","admissions.sat_scores.midpoint.writing","admissions.sat_scores.midpoint.math","admissions.act_scores.midpoint.cumulative",
    "academics.program_percentage.computer","academics.program_percentage.mathematics",
    "student.demographics.median_hh_income","student.size","student.demographics.female_share","student.demographics.race_ethnicity.white","student.demographics.race_ethnicity.black","student.demographics.race_ethnicity.hispanic","student.demographics.race_ethnicity.asian",
    "cost.net_price.public.by_income_level.48001-75000","cost.net_price.public.by_income_level.75001-110000","cost.attendance.academic_year","cost.tuition.in_state","cost.tuition.out_of_state",
    "aid.federal_loan_rate",
    "earnings.10_yrs_after_entry.median","earnings.6_yrs_after_entry.median"
])
collegeInfo = pd.DataFrame(scorecard.fetch_all()).sort_values(by='school.state').set_index(['school.state','school.name']).drop_duplicates(keep='first').fillna(value=np.nan)
collegeInfo"""
